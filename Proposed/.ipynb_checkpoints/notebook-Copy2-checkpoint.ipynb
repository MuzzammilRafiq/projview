# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os.path as osp
import glob
import cv2
import numpy as np
import torch
import RRDBNet_arch as arch

# %%
model_path = 'models/RRDB_ESRGAN_x4.pth'  # models/RRDB_ESRGAN_x4.pth OR models/RRDB_PSNR_x4.pth
device = torch.device('cpu')  # if you want to run on CPU, change 'cuda' -> cpu
test_img_folder = 'archive/glioma_tumor/*'

# %%
model = arch.RRDBNet(3, 3, 64, 23, gc=32)
model.load_state_dict(torch.load(model_path), strict=True)
model.eval()
model = model.to(device)

print('Model path {:s}. \nTesting...'.format(model_path))

idx = 0
# Out:
# Model path models/RRDB_ESRGAN_x4.pth.
# Testing...

# %%
for path in glob.glob(test_img_folder):
    idx += 1
    base = osp.splitext(osp.basename(path))[0]
    print(idx, base)
    # read images
    img = cv2.imread(path, cv2.IMREAD_COLOR)
    img = img * 1.0 / 255
    img = torch.from_numpy(np.transpose(img[:, :, [2, 1, 0]], (2, 0, 1))).float()
    img_LR = img.unsqueeze(0)
    img_LR = img_LR.to(device)

    with torch.no_grad():
        output = model(img_LR).data.squeeze().float().cpu().clamp_(0, 1).numpy()
    output = np.transpose(output[[2, 1, 0], :, :], (1, 2, 0))
    output = (output * 255.0).round()
    cv2.imwrite('output/gliomatumor/{:s}_rlt.png'.format(base), output)
# Out:
# 1 gg (1)
# 2 gg (10)
# 3 gg (100)
# 4 gg (101)
# 5 gg (102)
# 6 gg (103)
# 7 gg (104)
# 8 gg (105)
# 9 gg (106)
# 10 gg (107)
# 11 gg (108)
# 12 gg (109)
# 13 gg (11)
# 14 gg (110)
# 15 gg (111)
# 16 gg (112)
# 17 gg (113)
# 18 gg (114)
# 19 gg (115)
# 20 gg (116)
# 21 gg (117)
# 22 gg (118)
# 23 gg (119)
# 24 gg (12)
# 25 gg (120)
# 26 gg (121)
# 27 gg (122)
# 28 gg (123)
# 29 gg (124)
# 30 gg (125)
# 31 gg (126)
# 32 gg (127)
# 33 gg (128)
# 34 gg (129)
# 35 gg (13)
# 36 gg (130)
# 37 gg (131)
# 38 gg (132)
# 39 gg (133)
# 40 gg (134)
# 41 gg (135)
# 42 gg (136)
# 43 gg (137)
# 44 gg (138)
# 45 gg (139)
# 46 gg (14)
# 47 gg (140)
# 48 gg (141)
# 49 gg (142)
# 50 gg (143)
# 51 gg (144)
# 52 gg (145)
# 53 gg (146)
# 54 gg (147)
# 55 gg (148)
# 56 gg (149)
# 57 gg (15)
# 58 gg (150)
# 59 gg (151)
# 60 gg (152)
# 61 gg (153)
# 62 gg (154)
# 63 gg (155)
# 64 gg (156)
# 65 gg (157)
# 66 gg (158)
# 67 gg (159)
# 68 gg (16)
# 69 gg (160)
# 70 gg (161)
# 71 gg (162)
# 72 gg (163)
# 73 gg (164)
# 74 gg (165)
# 75 gg (166)
# 76 gg (167)
# 77 gg (168)
# 78 gg (169)
# 79 gg (17)
# 80 gg (170)
# 81 gg (171)
# 82 gg (172)
# 83 gg (173)
# 84 gg (174)
# 85 gg (175)
# 86 gg (176)
# 87 gg (177)
# 88 gg (178)
# 89 gg (179)
# 90 gg (18)
# 91 gg (180)
# 92 gg (181)
# 93 gg (182)
# 94 gg (183)
# 725 gg (751)
# 726 gg (752)
# 727 gg (753)
# 728 gg (754)
# 729 gg (755)
# 730 gg (756)
# 731 gg (757)
# 732 gg (758)
# 733 gg (759)
# 734 gg (76)
# 735 gg (760)
# 736 gg (761)
# 737 gg (762)
# 738 gg (763)
# 739 gg (764)
# 740 gg (765)
# 741 gg (766)
# 742 gg (767)
# 743 gg (768)
# 744 gg (769)
# 745 gg (77)
# 746 gg (770)
# 747 gg (771)
# 748 gg (772)
# 749 gg (773)
# 750 gg (774)
# 751 gg (775)
# 752 gg (776)
# 753 gg (777)
# 754 gg (778)
# 755 gg (779)
# 756 gg (78)
# 757 gg (780)
# 758 gg (781)
# 759 gg (782)
# 760 gg (783)
# 761 gg (784)
# 762 gg (785)
# 763 gg (786)
# 764 gg (787)
# 765 gg (788)
# 766 gg (789)
# 767 gg (79)
# 768 gg (790)
# 769 gg (791)
# 770 gg (792)
# 771 gg (793)
# 772 gg (794)
# 773 gg (795)
# 774 gg (796)
# 775 gg (797)
# 776 gg (798)
# 777 gg (799)
# 778 gg (8)
# 779 gg (80)
# 780 gg (800)
# 781 gg (801)
# 782 gg (802)
# 783 gg (803)
# 784 gg (804)
# 785 gg (805)
# 786 gg (806)
# 787 gg (807)
# 788 gg (808)
# 789 gg (809)
# 790 gg (81)
# 791 gg (810)
# 792 gg (811)
# 793 gg (812)
# 794 gg (813)
# 795 gg (814)
# 796 gg (815)
# 797 gg (816)
# 798 gg (817)
# 799 gg (818)
# 800 gg (819)
# 801 gg (82)
# 802 gg (820)
# 803 gg (821)
# 804 gg (822)
# 805 gg (823)
# 806 gg (824)
# 807 gg (825)
# 808 gg (826)
# 809 gg (83)
# 810 gg (84)
# 811 gg (85)
# 812 gg (86)
# 813 gg (87)
# 814 gg (88)
# 815 gg (89)
# 816 gg (9)
# 817 gg (90)
# 818 gg (91)
# 819 gg (92)
# 820 gg (93)
# 821 gg (94)
# 822 gg (95)
# 823 gg (96)
# 824 gg (97)
# 825 gg (98)
# 826 gg (99)
# 827 image(1)
# 828 image(10)
# 829 image(11)
# 830 image(12)
# 831 image(13)
# 832 image(14)
# 833 image(15)
# 834 image(16)
# 835 image(17)
# 836 image(18)
# 837 image(19)
# 838 image(2)
# 839 image(20)
# 840 image(21)
# 841 image(22)
# 842 image(23)
# 843 image(24)
# 844 image(25)
# 845 image(26)
# 846 image(27)
# 847 image(28)
# 848 image(29)
# 849 image(3)
# 850 image(30)
# 851 image(31)
# 852 image(32)
# 853 image(33)
# 854 image(34)
# 855 image(35)
# 856 image(36)
# 857 image(37)
# 858 image(38)
# 859 image(39)
# 860 image(4)
# 861 image(40)
# 862 image(41)
# 863 image(42)
# 864 image(43)
# 865 image(44)
# 866 image(45)
# 867 image(46)
# 868 image(47)
# 869 image(48)
# 870 image(49)
# 871 image(5)
# 872 image(51)
# 873 image(52)
# 874 image(53)
# 875 image(54)
# 876 image(56)
# 877 image(57)
# 878 image(58)
# 879 image(59)
# 880 image(6)
# 881 image(60)
# 882 image(61)
# 883 image(62)
# 884 image(63)
# 885 image(64)
# 886 image(65)
# 887 image(66)
# 888 image(67)
# 889 image(68)
# 890 image(69)
# 891 image(7)
# 892 image(70)
# 893 image(71)
# 894 image(72)
# 895 image(73)
# 896 image(74)
# 897 image(75)
# 898 image(76)
# 899 image(8)
# 900 image(9)

# %%
test_img_folder = 'archive/pituitary_tumor/*'

# %%
model = arch.RRDBNet(3, 3, 64, 23, gc=32)
model.load_state_dict(torch.load(model_path), strict=True)
model.eval()
model = model.to(device)

print('Model path {:s}. \nTesting...'.format(model_path))

idx = 0
# Out:
# Model path models/RRDB_ESRGAN_x4.pth.
# Testing...

# %%
for path in glob.glob(test_img_folder):
    idx += 1
    base = osp.splitext(osp.basename(path))[0]
    print(idx, base)
    # read images
    img = cv2.imread(path, cv2.IMREAD_COLOR)
    img = img * 1.0 / 255
    img = torch.from_numpy(np.transpose(img[:, :, [2, 1, 0]], (2, 0, 1))).float()
    img_LR = img.unsqueeze(0)
    img_LR = img_LR.to(device)

    with torch.no_grad():
        output = model(img_LR).data.squeeze().float().cpu().clamp_(0, 1).numpy()
    output = np.transpose(output[[2, 1, 0], :, :], (1, 2, 0))
    output = (output * 255.0).round()
    cv2.imwrite('output/pituitarytumor/{:s}_rlt.png'.format(base), output)
# Out:
# 1 image(1)
# 2 image(10)
# 3 image(11)
# 4 image(13)
# 5 image(15)
# 6 image(18)
# 7 image(19)
# 8 image(2)
# 9 image(20)
# 10 image(21)
# 11 image(22)
# 12 image(23)
# 13 image(27)
# 14 image(28)
# 15 image(3)
# 16 image(30)
# 17 image(31)
# 18 image(34)
# 19 image(35)
# 20 image(36)
# 21 image(37)
# 22 image(38)
# 23 image(41)
# 24 image(42)
# 25 image(43)
# 26 image(44)
# 27 image(45)
# 28 image(46)
# 29 image(47)
# 30 image(48)
# 31 image(49)
# 32 image(5)
# 33 image(51)
# 34 image(52)
# 35 image(53)
# 36 image(54)
# 37 image(55)
# 38 image(56)
# 39 image(57)
# 40 image(6)
# 41 image(60)
# 42 image(61)
# 43 image(63)
# 44 image(64)
# 45 image(65)
# 46 image(66)
# 47 image(67)
# 48 image(68)
# 49 image(69)
# 50 image(7)
# 51 image(70)
# 52 image(73)
# 53 image(76)
# 54 image(77)
# 55 image(78)
# 56 image(79)
# 57 image(8)
# 58 image(81)
# 59 image(82)
# 60 image(85)
# 61 image(86)
# 62 image(87)
# 63 image(88)
# 64 image(89)
# 65 image(90)
# 66 image(91)
# 67 image(92)
# 68 image(93)
# 69 image(94)
# 70 image(95)
# 71 image(96)
# 72 image(97)
# 73 image(98)
# 74 image
# 75 p (1)
# 76 p (10)
# 77 p (100)
# 78 p (101)
# 79 p (102)
# 80 p (103)
# 81 p (104)
# 82 p (105)
# 83 p (106)
# 84 p (107)
# 85 p (108)
# 86 p (109)
# 87 p (11)
# 88 p (110)
# 89 p (111)
# 90 p (112)
# 91 p (113)
# 92 p (114)
# 93 p (115)
# 94 p (116)
# 95 p (117)
# 96 p (118)
# 97 p (119)
# 98 p (12)
# 99 p (120)
# 100 p (121)
# 101 p (122)
# 102 p (123)
# 103 p (124)
# 104 p (125)
# 105 p (126)
# 106 p (127)
# 107 p (128)
# 108 p (129)
# 109 p (13)
# 810 p (761)
# 811 p (762)
# 812 p (763)
# 813 p (764)
# 814 p (765)
# 815 p (766)
# 816 p (767)
# 817 p (768)
# 818 p (769)
# 819 p (77)
# 820 p (770)
# 821 p (771)
# 822 p (772)
# 823 p (773)
# 824 p (774)
# 825 p (775)
# 826 p (776)
# 827 p (777)
# 828 p (778)
# 829 p (779)
# 830 p (78)
# 831 p (780)
# 832 p (781)
# 833 p (782)
# 834 p (783)
# 835 p (784)
# 836 p (785)
# 837 p (786)
# 838 p (787)
# 839 p (788)
# 840 p (789)
# 841 p (79)
# 842 p (790)
# 843 p (791)
# 844 p (792)
# 845 p (793)
# 846 p (794)
# 847 p (795)
# 848 p (796)
# 849 p (797)
# 850 p (798)
# 851 p (799)
# 852 p (8)
# 853 p (80)
# 854 p (800)
# 855 p (801)
# 856 p (802)
# 857 p (803)
# 858 p (804)
# 859 p (805)
# 860 p (806)
# 861 p (807)
# 862 p (808)
# 863 p (809)
# 864 p (81)
# 865 p (810)
# 866 p (811)
# 867 p (812)
# 868 p (813)
# 869 p (814)
# 870 p (815)
# 871 p (816)
# 872 p (817)
# 873 p (818)
# 874 p (819)
# 875 p (82)
# 876 p (820)
# 877 p (821)
# 878 p (822)
# 879 p (823)
# 880 p (824)
# 881 p (825)
# 882 p (826)
# 883 p (83)
# 884 p (84)
# 885 p (85)
# 886 p (86)
# 887 p (87)
# 888 p (88)
# 889 p (89)
# 890 p (9)
# 891 p (90)
# 892 p (91)
# 893 p (92)
# 894 p (93)
# 895 p (94)
# 896 p (95)
# 897 p (96)
# 898 p (97)
# 899 p (98)
# 900 p (99)

# %% [markdown]
# # Analysis

# %%
import cv2
import random
import os
import keras
import re

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator, DataFrameIterator
from keras.metrics import Precision, Recall
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (
    Dense,
    Flatten,
    BatchNormalization,
    Conv2D,
    MaxPooling2D,
    GlobalAveragePooling2D,
    Dropout,
    Input,
    Activation,
    concatenate,
)
import tensorflow as tf

# %%
import splitfolders # or import splitfolders
input_folder = "output"
output = "data" #where you want the split datasets saved. one will be created if it does not exist or none is set

splitfolders.ratio(input_folder, output=output, seed=42, ratio=(.8, .2)) # ratio of split are in order of train/val/test. You can change to whatever you want. For train/val sets only, you could do .75, .25 for example.
# Out:
# Copying files: 1800 files [00:04, 371.31 files/s]

# %%
# Resizinig all the images to (224,224)
IMAGE_SIZE = [128,128]

train_path1 = 'data/train'
test_path1 = 'data/val'

# %%
# Scaling all the images between 0 to 1

train_datagen1 = ImageDataGenerator(rescale = 1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=False)

# Performing only scaling on the test dataset

test_datagen1 = ImageDataGenerator(rescale=1./255)

# %%
train_data_gen = train_datagen1.flow_from_directory(train_path1,
                                              target_size=(128,128),
                                              batch_size=2,
                                              class_mode = 'categorical')

val_data_gen = test_datagen1.flow_from_directory(test_path1,
                                            target_size=(128,128),
                                            batch_size=2,
                                            class_mode='categorical')
# Out:
# Found 1440 images belonging to 2 classes.
# Found 360 images belonging to 2 classes.

# %%
from keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# # VGG19

# %%
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.models import Model
vgg19=VGG19(input_shape = IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# %%
x11= Flatten()(vgg19.output)
prediction11 = Dense(2, activation='softmax')(x11)
model11 = Model(inputs = vgg19.inputs, outputs = prediction11)
model11.summary()
model11.compile(loss = 'categorical_crossentropy', optimizer='adam', metrics=['accuracy',f1_m,precision_m, recall_m])
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 128, 128, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 128, 128, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 64, 64, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 64, 64, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 64, 64, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 32, 32, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 32, 32, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 16, 16, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 16, 16, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 16386
# =================================================================
# Total params: 20,040,770
# Trainable params: 20,040,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
learning_rate_reduction = ReduceLROnPlateau(
    monitor="val_accuracy", patience=3, verbose=1, factor=0.3, min_lr=0.0000001
)
early_stop = EarlyStopping(
    patience=10,
    verbose=1,
    monitor="val_accuracy",
    mode="max",
    min_delta=0.001,
    restore_best_weights=True,
)
history = model11.fit_generator(train_data_gen, validation_data=train_data_gen, epochs=200, steps_per_epoch=len(train_data_gen), validation_steps=len(train_data_gen),callbacks=[learning_rate_reduction, early_stop],)
# Out:
# Epoch 1/200
# 720/720 [==============================] - 696s 966ms/step - loss: 1.7831 - accuracy: 0.4917 - f1_m: 0.4917 - precision_m: 0.4917 - recall_m: 0.4917 - val_loss: 0.6931 - val_accuracy: 0.5000 - val_f1_m: 0.5000 - val_precision_m: 0.5000 - val_recall_m: 0.5000
# Epoch 2/200
# 720/720 [==============================] - 687s 954ms/step - loss: 0.6935 - accuracy: 0.4861 - f1_m: 0.4861 - precision_m: 0.4861 - recall_m: 0.4861 - val_loss: 0.6931 - val_accuracy: 0.5000 - val_f1_m: 0.5000 - val_precision_m: 0.5000 - val_recall_m: 0.5000
# Epoch 3/200
# 720/720 [==============================] - 684s 950ms/step - loss: 0.6934 - accuracy: 0.4903 - f1_m: 0.4903 - precision_m: 0.4903 - recall_m: 0.4903 - val_loss: 0.6931 - val_accuracy: 0.5000 - val_f1_m: 0.5000 - val_precision_m: 0.5000 - val_recall_m: 0.5000
# Epoch 4/200
# 720/720 [==============================] - 684s 950ms/step - loss: 0.6935 - accuracy: 0.4736 - f1_m: 0.4736 - precision_m: 0.4736 - recall_m: 0.4736 - val_loss: 0.6931 - val_accuracy: 0.5000 - val_f1_m: 0.5000 - val_precision_m: 0.5000 - val_recall_m: 0.5000
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# Epoch 5/200
# 720/720 [==============================] - 688s 957ms/step - loss: 0.6933 - accuracy: 0.4986 - f1_m: 0.4986 - precision_m: 0.4986 - recall_m: 0.4986 - val_loss: 0.6931 - val_accuracy: 0.5000 - val_f1_m: 0.5000 - val_precision_m: 0.5000 - val_recall_m: 0.5000
# Epoch 6/200
# 512/720 [====================>.........] - ETA: 2:22 - loss: 0.6932 - accuracy: 0.5068 - f1_m: 0.5068 - precision_m: 0.5068 - recall_m: 0.5068

# %%
vgg_acc = history.history["val_accuracy"]
vgg_prec = history.history["val_precision_m"]
vgg_rec = history.history["val_recall_m"]
vgg_f1 = history.history["val_f1_m"]

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)
ax1.plot(history.history["loss"], color="b", label="Training loss")
ax1.plot(history.history["val_loss"], color="r", label="validation loss")
ax1.legend()

ax2.plot(history.history["accuracy"], color="b", label="Training accuracy")
ax2.plot(history.history["val_accuracy"], color="r", label="Validation accuracy")
ax2.legend()

legend = plt.legend(loc="best")
plt.tight_layout()
plt.show()

# %% [markdown]
# # ResNet101

# %%
from tensorflow.keras.applications.resnet import ResNet101

# %%
res = ResNet101(input_shape = IMAGE_SIZE + [3], weights='imagenet', include_top=False)
x11= Flatten()(res.output)
prediction11 = Dense(2, activation='softmax')(x11)
model1 = Model(inputs = res.inputs, outputs = prediction11)
model1.summary()
model1.compile(loss = 'categorical_crossentropy', optimizer='adam', metrics=['accuracy',f1_m,precision_m, recall_m])

# %%
history1 = model1.fit_generator(train_data_gen, validation_data=train_data_gen, epochs=200, steps_per_epoch=len(train_data_gen), validation_steps=len(train_data_gen),callbacks=[learning_rate_reduction, early_stop],)

# %%
res_acc = history1.history["val_accuracy"]
res_prec = history1.history["val_precision_m"]
res_rec = history1.history["val_recall_m"]
res_f1 = history1.history["val_f1_m"]

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)
ax1.plot(history1.history["loss"], color="b", label="Training loss")
ax1.plot(history1.history["val_loss"], color="r", label="validation loss")
ax1.legend()

ax2.plot(history1.history["accuracy"], color="b", label="Training accuracy")
ax2.plot(history1.history["val_accuracy"], color="r", label="Validation accuracy")
ax2.legend()

legend = plt.legend(loc="best")
plt.tight_layout()
plt.show()

# %% [markdown]
# # MobileNet

# %%
from tensorflow.keras.applications import MobileNet
mob = MobileNet(input_shape = IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# %%
x1= Flatten()(mob.output)
prediction1 = Dense(2, activation='softmax')(x1)
model12 = Model(inputs = mob.inputs, outputs = prediction1)
model12.summary()
model12.compile(loss = 'categorical_crossentropy', optimizer='adam', metrics=['accuracy',f1_m,precision_m, recall_m])

# %%
history2 = model12.fit_generator(train_data_gen, validation_data=train_data_gen, epochs=200, steps_per_epoch=len(train_data_gen), validation_steps=len(train_data_gen),callbacks=[learning_rate_reduction, early_stop],)

# %%
model12.save('mobile.h5')

# %%
mob_acc = history2.history["val_accuracy"]
mob_prec = history2.history["val_precision_m"]
mob_rec = history2.history["val_recall_m"]
mob_f1 = history2.history["val_f1_m"]

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)
ax1.plot(history2.history["loss"], color="b", label="Training loss")
ax1.plot(history2.history["val_loss"], color="r", label="validation loss")
ax1.legend()

ax2.plot(history2.history["accuracy"], color="b", label="Training accuracy")
ax2.plot(history2.history["val_accuracy"], color="r", label="Validation accuracy")
ax2.legend()

legend = plt.legend(loc="best")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Xception

# %%
from keras.applications.xception import Xception
from keras.layers import Activation, Dense,GlobalAveragePooling2D, Dropout
from keras.models import Model

# %%
# Defining the pretrained base model
base = Xception(include_top=False, weights='imagenet', input_shape=(128,128,3))
x = base.output
x = GlobalAveragePooling2D()(x)
# Defining the head of the model where the prediction is conducted
head = Dense(2, activation='softmax')(x)
# Combining base and head 
model3 = Model(inputs=base.input, outputs=head)

# Compiling the model
model3.compile(loss = keras.losses.categorical_crossentropy, optimizer= 'adam', metrics=['accuracy',f1_m,precision_m, recall_m])

# %%
history3 = model3.fit_generator(train_data_gen, validation_data=train_data_gen, epochs=200, steps_per_epoch=len(train_data_gen), validation_steps=len(train_data_gen),callbacks=[learning_rate_reduction, early_stop],)

# %%
model3.save('xec.h5')

# %%
xec_acc = history3.history["val_accuracy"]
xec_prec = history3.history["val_precision_m"]
xec_rec = history3.history["val_recall_m"]
xec_f1 = history3.history["val_f1_m"]

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)
ax1.plot(history3.history["loss"], color="b", label="Training loss")
ax1.plot(history3.history["val_loss"], color="r", label="validation loss")
ax1.legend()

ax2.plot(history3.history["accuracy"], color="b", label="Training accuracy")
ax2.plot(history3.history["val_accuracy"], color="r", label="Validation accuracy")
ax2.legend()

legend = plt.legend(loc="best")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Xception + MobileNet

# %%
import efficientnet.keras 
def ensemble():

    model_1 = load_model('mobile.h5', compile=False)
    model_1 = Model(inputs = model_1.inputs, outputs = model_1.outputs, name = 'MobileNet')

    model_2 = load_model('xec.h5', compile=False)
    model_2 = Model(inputs = model_2.inputs, outputs = model_2.outputs, name = 'Xception')


    models = [model_1, model_2]


    models_input = Input(shape =(128,128,3))
    models_output = [model(models_input) for model in models]
    
    ensemble_output = Average()(models_output)

    simple_average = Model(inputs = models_input, outputs = ensemble_output, name = 'Ensemble')

    return simple_average

# %%
model = ensemble()
model.summary()

# %%
model.compile(loss = keras.losses.categorical_crossentropy, optimizer= 'adam', metrics=['accuracy',f1_m,precision_m, recall_m])

# %%
hist = model.fit_generator(train_data_gen, validation_data=train_data_gen, epochs=200, steps_per_epoch=len(train_data_gen), validation_steps=len(train_data_gen),callbacks=[learning_rate_reduction, early_stop],)
